# %% [markdown]
# # QUAST Assessment for FLYE Chr 22 5mb

# %%
# imports
# Biopython imports
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import DNAAlphabet
from Bio import SeqIO

# %%
# obtain all contigs to one file
project_name = "chr22"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa"

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/chr22/contigs/contig_1' \
'../Improving_Assembly_Graph/chr22/contigs/contig_2' \
'../Improving_Assembly_Graph/chr22/contigs/contig_3' \
'../Improving_Assembly_Graph/chr22/contigs/contig_4' \
'../Improving_Assembly_Graph/chr22/contigs/contig_5' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all -o ./chr22/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa -t 16 ./chr22/contigs/contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-02 09:42:55
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa ==> chr22_5mb
#
# Contigs:
#   Pre-processing...
#   ./chr22/contigs/contigs.fasta ==> contigs
#
# 2019-01-02 09:42:56
# Running Basic statistics processor...
#   Reference genome:
#     chr22_5mb.fa, length = 5000000, num fragments = 1, GC % = 45.41
#   Contig files:
#     contigs
#   Calculating N50 and L50...
#     contigs, N50 = 4381954, L50 = 1, Total length = 4967640, GC % = 45.64, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/basic_stats/contigs_GC_content_plot.pdf
# Done.
#
# 2019-01-02 09:42:57
# Running Contig analyzer...
#   contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/contigs_reports/contigs_report_contigs.stdout and contigs_report_contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-02 09:43:01
# Running NA-NGA calculation...
#   contigs, Largest alignment = 4377749, NA50 = 4377749, NGA50 = 4377749, LA50 = 1, LGA50 = 1
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-02 09:43:01
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-02 09:43:02
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-02 09:43:03
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22/quast_eval/quast.log
#
# Finished: 2019-01-02 09:43:03
# Elapsed time: 0:00:07.601909
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.117*1.01] collected minimizers
# [M::mm_idx_gen::0.140*1.33] sorted minimizers
# [M::main::0.140*1.33] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.150*1.31] mid_occ = 104
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.159*1.29] distinct minimizers: 799170 (95.15% are singletons); average occurrences: 1.182; average spacing: 5.292
# [M::worker_pipeline::6.196*1.04] mapped 5 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa ./chr22/contigs/contigs.fasta
# [M::main] Real time: 6.201 sec; CPU: 6.470 sec; Peak RSS: 0.179 GB

# %%
# chunk and align

# obtain all contigs to one file
project_name = "chr22_chunk_align"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa"

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
# !mkdir "$project_name/chunks"

chunks = []
with open(reference_genome, 'r') as f:
    content = f.read().strip().split('\n')
    content.pop(0)
    
    string = "".join(content)
    index = 0
    
    while index < len(string):
        chunks.append(string[index:index+10000].upper())
        index += 5000

chunk_index = 0
records = []
for c in chunks:
    r = SeqRecord(Seq(c, DNAAlphabet), id="Chunk_"+str(chunk_index), description="Generated Chunk" + str(chunk_index) + "-" + str(chunk_index + 10000))
    SeqIO.write(r, project_name+"/chunks/"+str(chunk_index) + ".fa", "fasta")
    chunk_index += 5000
    records.append(r)

SeqIO.write(records, project_name+"/chunks/all.fa", "fasta")

![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/chr22/contigs/contig_1' \
'../Improving_Assembly_Graph/chr22/contigs/contig_2' \
'../Improving_Assembly_Graph/chr22/contigs/contig_3' \
'../Improving_Assembly_Graph/chr22/contigs/contig_4' \
'../Improving_Assembly_Graph/chr22/contigs/contig_5' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$project_name"/chunks/all.fa ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# # !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# # !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# [M::mm_idx_gen::0.303*1.00] collected minimizers
# [M::mm_idx_gen::0.392*1.37] sorted minimizers
# [M::main::0.392*1.37] loaded/built the index for 1000 target sequence(s)
# [M::mm_mapopt_update::0.408*1.36] mid_occ = 206
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1000
# [M::mm_idx_stat::0.418*1.35] distinct minimizers: 799170 (0.43% are singletons); average occurrences: 2.359; average spacing: 5.302
# [M::worker_pipeline::12.922*1.05] mapped 5 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a chr22_chunk_align/chunks/all.fa ./chr22_chunk_align/contigs/contigs.fasta
# [M::main] Real time: 12.928 sec; CPU: 13.638 sec; Peak RSS: 0.305 GB

# %% [markdown]
# # QUAST Assessment for Canu Chr 22 5mb

# %%
# obtain all contigs to one file
project_name = "chr22canu"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa"


![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval 

# !quast.py -a all -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Chr22/r1.contigs.fasta"

# !minimap2 -a "$reference_genome" "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Chr22/r1.contigs.fasta" > ./"$project_name"/mappings/CANU_alignment.sam
# !samtools sort ./"$project_name"/mappings/CANU_alignment.sam > ./"$project_name"/mappings/CANU_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/CANU_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all -o ./chr22canu/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa -t 16 /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Chr22/r1.contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-42-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2018-12-20 14:00:14
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa ==> chr22_5mb
#
# Contigs:
#   Pre-processing...
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Chr22/r1.contigs.fasta ==> r1.contigs
#
# 2018-12-20 14:00:14
# Running Basic statistics processor...
#   Reference genome:
#     chr22_5mb.fa, length = 5000000, num fragments = 1, GC % = 45.41
#   Contig files:
#     r1.contigs
#   Calculating N50 and L50...
#     r1.contigs, N50 = 4995129, L50 = 1, Total length = 5020595, GC % = 45.44, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing r1.contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/basic_stats/r1.contigs_GC_content_plot.pdf
# Done.
#
# 2018-12-20 14:00:15
# Running Contig analyzer...
#   r1.contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/contigs_reports/contigs_report_r1-contigs.stdout and contigs_report_r1-contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2018-12-20 14:00:20
# Running NA-NGA calculation...
#   r1.contigs, Largest alignment = 4995129, NA50 = 4995129, NGA50 = 4995129, LA50 = 1, LGA50 = 1
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2018-12-20 14:00:20
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   r1.contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2018-12-20 14:00:21
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2018-12-20 14:00:22
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22canu/quast_eval/quast.log
#
# Finished: 2018-12-20 14:00:22
# Elapsed time: 0:00:08.471711
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.109*1.01] collected minimizers
# [M::mm_idx_gen::0.132*1.35] sorted minimizers
# [M::main::0.132*1.35] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.142*1.33] mid_occ = 104
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.149*1.31] distinct minimizers: 799170 (95.15% are singletons); average occurrences: 1.182; average spacing: 5.292
# [M::worker_pipeline::8.752*1.01] mapped 2 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Chr22/r1.contigs.fasta
# [M::main] Real time: 8.757 sec; CPU: 8.816 sec; Peak RSS: 0.169 GB

# %%
# obtain all contigs to one file
project_name = "r4"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/G4.fa"

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings

# !cat \
'/media/anuradhawick/data/Experiments/Assembly_Graph/Improving_Assembly_Graph/simG4/contigs/contig_1' \
'/media/anuradhawick/data/Experiments/Assembly_Graph/Improving_Assembly_Graph/simG4/contigs/contig_2' \
'/media/anuradhawick/data/Experiments/Assembly_Graph/Improving_Assembly_Graph/simG4/contigs/contig_3' \
> ./"$project_name"/contigs/contigs.fasta 


# !quast.py -a all -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all -o ./r4/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/G4.fa -t 16 ./r4/contigs/contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-42-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2018-12-20 13:59:31
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/G4.fa ==> G4
#
# Contigs:
#   Pre-processing...
#   ./r4/contigs/contigs.fasta ==> contigs
#
# 2018-12-20 13:59:31
# Running Basic statistics processor...
#   Reference genome:
#     G4.fa, length = 5000000, num fragments = 1, GC % = 50.02
#   Contig files:
#     contigs
#   Calculating N50 and L50...
#     contigs, N50 = 1749925, L50 = 2, Total length = 4374913, GC % = 50.02, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/basic_stats/contigs_GC_content_plot.pdf
# Done.
#
# 2018-12-20 13:59:33
# Running Contig analyzer...
#   contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/contigs_reports/contigs_report_contigs.stdout and contigs_report_contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2018-12-20 13:59:34
# Running NA-NGA calculation...
#   contigs, Largest alignment = 1999988, NA50 = 1749925, NGA50 = 1749925, LA50 = 2, LGA50 = 2
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2018-12-20 13:59:34
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2018-12-20 13:59:35
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2018-12-20 13:59:36
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/r4/quast_eval/quast.log
#
# Finished: 2018-12-20 13:59:36
# Elapsed time: 0:00:05.359214
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.151*1.01] collected minimizers
# [M::mm_idx_gen::0.177*1.30] sorted minimizers
# [M::main::0.177*1.30] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.190*1.28] mid_occ = 4
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.199*1.26] distinct minimizers: 813698 (85.49% are singletons); average occurrences: 1.146; average spacing: 5.363
# [M::worker_pipeline::0.670*2.07] mapped 3 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/G4.fa ./r4/contigs/contigs.fasta
# [M::main] Real time: 0.676 sec; CPU: 1.396 sec; Peak RSS: 0.132 GB

# %%
project_name = "chr22_contig5"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa"
 

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/chr22/contigs/contig_4' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all --ambiguity-score 0.8 -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 "../Improving_Assembly_Graph/chr22/contigs/contig_5"

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all --ambiguity-score 0.8 -o ./chr22_contig5/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa -t 16 ../Improving_Assembly_Graph/chr22/contigs/contig_5
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-02 09:47:03
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa ==> chr22_5mb
#
# Contigs:
#   Pre-processing...
#   ../Improving_Assembly_Graph/chr22/contigs/contig_5 ==> contig_5
#
# 2019-01-02 09:47:04
# Running Basic statistics processor...
#   Reference genome:
#     chr22_5mb.fa, length = 5000000, num fragments = 1, GC % = 45.41
#   Contig files:
#     contig_5
#   Calculating N50 and L50...
#     contig_5, N50 = 6831, L50 = 1, Total length = 6831, GC % = 36.52, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contig_5 GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/basic_stats/contig_5_GC_content_plot.pdf
# Done.
#
# 2019-01-02 09:47:04
# Running Contig analyzer...
#   contig_5
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/contigs_reports/contigs_report_contig_5.stdout and contigs_report_contig_5.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-02 09:47:05
# Running NA-NGA calculation...
#   contig_5, Largest alignment = 6831, NA50 = 6831, LA50 = 1
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-02 09:47:05
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contig_5
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-02 09:47:06
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-02 09:47:07
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig5/quast_eval/quast.log
#
# Finished: 2019-01-02 09:47:07
# Elapsed time: 0:00:03.456713
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!

# %%
project_name = "chr22_contig4"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa"
 

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/chr22/contigs/contig_4' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all --ambiguity-score 0.8 -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all --ambiguity-score 0.8 -o ./chr22_contig4/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa -t 16 ./chr22_contig4/contigs/contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-02 09:49:53
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/chr22_5mb.fa ==> chr22_5mb
#
# Contigs:
#   Pre-processing...
#   ./chr22_contig4/contigs/contigs.fasta ==> contigs
#
# 2019-01-02 09:49:53
# Running Basic statistics processor...
#   Reference genome:
#     chr22_5mb.fa, length = 5000000, num fragments = 1, GC % = 45.41
#   Contig files:
#     contigs
#   Calculating N50 and L50...
#     contigs, N50 = 29485, L50 = 1, Total length = 29485, GC % = 44.16, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/basic_stats/contigs_GC_content_plot.pdf
# Done.
#
# 2019-01-02 09:49:54
# Running Contig analyzer...
#   contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/contigs_reports/contigs_report_contigs.stdout and contigs_report_contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-02 09:49:54
# Running NA-NGA calculation...
#   contigs, Largest alignment = 29485, NA50 = 29485, LA50 = 1
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-02 09:49:55
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-02 09:49:55
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-02 09:49:56
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4/quast_eval/quast.log
#
# Finished: 2019-01-02 09:49:56
# Elapsed time: 0:00:03.375383
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!

# %%
project_name = "chr22_contig4to2"
reference_genome = '../Improving_Assembly_Graph/chr22/contigs/contig_2'
 

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/chr22/contigs/contig_4' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all --ambiguity-score 0.8 -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all --ambiguity-score 0.8 -o ./chr22_contig4to2/quast_eval/ -r ../Improving_Assembly_Graph/chr22/contigs/contig_2 -t 16 ./chr22_contig4to2/contigs/contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-02 09:53:01
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Improving_Assembly_Graph/chr22/contigs/contig_2 ==> contig_2
#
# Contigs:
#   Pre-processing...
#   ./chr22_contig4to2/contigs/contigs.fasta ==> contigs
#
# 2019-01-02 09:53:01
# Running Basic statistics processor...
#   Reference genome:
#     contig_2, length = 266413, num fragments = 1, GC % = 47.67
#   Contig files:
#     contigs
#   Calculating N50 and L50...
#     contigs, N50 = 29485, L50 = 1, Total length = 29485, GC % = 44.16, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/basic_stats/contigs_GC_content_plot.pdf
# Done.
#
# 2019-01-02 09:53:02
# Running Contig analyzer...
#   contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/contigs_reports/contigs_report_contigs.stdout and contigs_report_contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-02 09:53:02
# Running NA-NGA calculation...
#   contigs, Largest alignment = 29485, NA50 = 29485, LA50 = 1
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-02 09:53:02
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-02 09:53:02
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-02 09:53:03
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_contig4to2/quast_eval/quast.log
#
# Finished: 2019-01-02 09:53:03
# Elapsed time: 0:00:01.756174
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.019*1.08] collected minimizers
# [M::mm_idx_gen::0.025*1.55] sorted minimizers
# [M::main::0.025*1.55] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.026*1.54] mid_occ = 39
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.027*1.53] distinct minimizers: 45547 (95.33% are singletons); average occurrences: 1.105; average spacing: 5.292
# [M::worker_pipeline::0.034*1.42] mapped 1 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a ../Improving_Assembly_Graph/chr22/contigs/contig_2 ./chr22_contig4to2/contigs/contigs.fasta
# [M::main] Real time: 0.035 sec; CPU: 0.049 sec; Peak RSS: 0.008 GB

# %%
project_name = "chr22_flye_to_canu"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/canutig22.fasta"
 

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval


# !quast.py -a all --ambiguity-score 0.8 -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 "/media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/flye2_4_5.fasta"
# !minimap2 -a "$reference_genome" "/media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/flye2_4_5.fasta" > ./"$project_name"/mappings/alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all --ambiguity-score 0.8 -o ./chr22_flye_to_canu/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/canutig22.fasta -t 16 /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/flye2_4_5.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-03 16:10:53
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/canutig22.fasta ==> canutig22
#
# Contigs:
#   Pre-processing...
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/flye2_4_5.fasta ==> flye2_4_5
#
# 2019-01-03 16:10:53
# Running Basic statistics processor...
#   Reference genome:
#     canutig22.fasta, length = 25466, num fragments = 1, GC % = 50.32
#   Contig files:
#     flye2_4_5
#   Calculating N50 and L50...
#     flye2_4_5, N50 = 266413, L50 = 1, Total length = 302729, GC % = 47.08, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing flye2_4_5 GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/basic_stats/flye2_4_5_GC_content_plot.pdf
# Done.
#
# 2019-01-03 16:10:54
# Running Contig analyzer...
#   flye2_4_5
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/contigs_reports/contigs_report_flye2_4_5.stdout and contigs_report_flye2_4_5.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-03 16:10:54
# Running NA-NGA calculation...
#   flye2_4_5, Largest alignment = 140, NA50 = None, LA50 = None
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-03 16:10:54
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   flye2_4_5
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-03 16:10:54
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-03 16:10:55
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/chr22_flye_to_canu/quast_eval/quast.log
#
# Finished: 2019-01-03 16:10:55
# Elapsed time: 0:00:02.542194
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.003*1.47] collected minimizers
# [M::mm_idx_gen::0.005*1.90] sorted minimizers
# [M::main::0.005*1.89] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.006*1.81] mid_occ = 24
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.006*1.76] distinct minimizers: 4201 (94.14% are singletons); average occurrences: 1.169; average spacing: 5.186
# [M::worker_pipeline::0.512*1.16] mapped 3 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/canutig22.fasta /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/canu_contigs_chr22/flye2_4_5.fasta
# [M::main] Real time: 0.513 sec; CPU: 0.595 sec; Peak RSS: 0.167 GB

# %% [markdown]
# # Yeast Genome Contig Realignment

# %%
project_name = "yeastgenome"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa"

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/yeast/contigs/contig_1' \
'../Improving_Assembly_Graph/yeast/contigs/contig_2' \
'../Improving_Assembly_Graph/yeast/contigs/contig_3' \
'../Improving_Assembly_Graph/yeast/contigs/contig_4' \
'../Improving_Assembly_Graph/yeast/contigs/contig_5' \
'../Improving_Assembly_Graph/yeast/contigs/contig_6' \
'../Improving_Assembly_Graph/yeast/contigs/contig_7' \
'../Improving_Assembly_Graph/yeast/contigs/contig_8' \
'../Improving_Assembly_Graph/yeast/contigs/contig_9' \
'../Improving_Assembly_Graph/yeast/contigs/contig_10' \
'../Improving_Assembly_Graph/yeast/contigs/contig_11' \
'../Improving_Assembly_Graph/yeast/contigs/contig_12' \
'../Improving_Assembly_Graph/yeast/contigs/contig_13' \
'../Improving_Assembly_Graph/yeast/contigs/contig_14' \
'../Improving_Assembly_Graph/yeast/contigs/contig_15' \
'../Improving_Assembly_Graph/yeast/contigs/contig_16' \
'../Improving_Assembly_Graph/yeast/contigs/contig_17' \
'../Improving_Assembly_Graph/yeast/contigs/contig_18' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all --ambiguity-score 0.8 -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all --ambiguity-score 0.8 -o ./yeastgenome/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa -t 16 ./yeastgenome/contigs/contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-04 13:35:20
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa ==> YeastGenome
#
# Contigs:
#   Pre-processing...
#   ./yeastgenome/contigs/contigs.fasta ==> contigs
#
# 2019-01-04 13:35:22
# Running Basic statistics processor...
#   Reference genome:
#     YeastGenome.fa, length = 12157105, num fragments = 1, GC % = 38.15
#   Contig files:
#     contigs
#   Calculating N50 and L50...
#     contigs, N50 = 2619345, L50 = 2, Total length = 12074401, GC % = 38.17, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/basic_stats/contigs_GC_content_plot.pdf
# Done.
#
# 2019-01-04 13:35:24
# Running Contig analyzer...
#   contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/contigs_reports/contigs_report_contigs.stdout and contigs_report_contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-04 13:35:29
# Running NA-NGA calculation...
#   contigs, Largest alignment = 5473509, NA50 = 1895493, NGA50 = 1895493, LA50 = 2, LGA50 = 2
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-04 13:35:30
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-04 13:35:34
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-04 13:35:35
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome/quast_eval/quast.log
#
# Finished: 2019-01-04 13:35:35
# Elapsed time: 0:00:14.328828
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.355*1.00] collected minimizers
# [M::mm_idx_gen::0.578*1.08] sorted minimizers
# [M::main::0.578*1.08] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.617*1.07] mid_occ = 33
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.644*1.07] distinct minimizers: 2084960 (95.68% are singletons); average occurrences: 1.093; average spacing: 5.336
# [M::worker_pipeline::3.342*1.83] mapped 18 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa ./yeastgenome/contigs/contigs.fasta
# [M::main] Real time: 3.350 sec; CPU: 6.137 sec; Peak RSS: 0.307 GB

# %%
project_name = "yeastgenome_refinedgraph"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa"

![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/contigs ] && mkdir "$project_name"/contigs
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval

# !cat \
'../Improving_Assembly_Graph/yeast/contigs/contig_1' \
'../Improving_Assembly_Graph/yeast/contigs/contig_2' \
'../Improving_Assembly_Graph/yeast/contigs/contig_3' \
'../Improving_Assembly_Graph/yeast/contigs/contig_4' \
'../Improving_Assembly_Graph/yeast/contigs/contig_5' \
'../Improving_Assembly_Graph/yeast/contigs/contig_6' \
'../Improving_Assembly_Graph/yeast/contigs/contig_15' \
> ./"$project_name"/contigs/contigs.fasta 

# !quast.py -a all --ambiguity-score 0.8 -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 ./"$project_name"/contigs/contigs.fasta

# !minimap2 -a "$reference_genome" ./"$project_name"/contigs/contigs.fasta > ./"$project_name"/mappings/FLYE_alignment.sam
# !samtools sort ./"$project_name"/mappings/FLYE_alignment.sam > ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# !samtools index -b ./"$project_name"/mappings/FLYE_alignment.sorted.bam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all --ambiguity-score 0.8 -o ./yeastgenome_refinedgraph/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa -t 16 ./yeastgenome_refinedgraph/contigs/contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-04 13:35:43
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa ==> YeastGenome
#
# Contigs:
#   Pre-processing...
#   ./yeastgenome_refinedgraph/contigs/contigs.fasta ==> contigs
#
# 2019-01-04 13:35:44
# Running Basic statistics processor...
#   Reference genome:
#     YeastGenome.fa, length = 12157105, num fragments = 1, GC % = 38.15
#   Contig files:
#     contigs
#   Calculating N50 and L50...
#     contigs, N50 = 2619345, L50 = 2, Total length = 12019949, GC % = 38.16, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/basic_stats/contigs_GC_content_plot.pdf
# Done.
#
# 2019-01-04 13:35:46
# Running Contig analyzer...
#   contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/contigs_reports/contigs_report_contigs.stdout and contigs_report_contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-04 13:35:52
# Running NA-NGA calculation...
#   contigs, Largest alignment = 5473509, NA50 = 1895493, NGA50 = 1895493, LA50 = 2, LGA50 = 2
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-04 13:35:52
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-04 13:35:56
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-04 13:35:57
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastgenome_refinedgraph/quast_eval/quast.log
#
# Finished: 2019-01-04 13:35:57
# Elapsed time: 0:00:14.357697
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
# [M::mm_idx_gen::0.360*0.99] collected minimizers
# [M::mm_idx_gen::0.549*1.13] sorted minimizers
# [M::main::0.549*1.13] loaded/built the index for 1 target sequence(s)
# [M::mm_mapopt_update::0.582*1.12] mid_occ = 33
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 1
# [M::mm_idx_stat::0.610*1.12] distinct minimizers: 2084960 (95.68% are singletons); average occurrences: 1.093; average spacing: 5.336
# [M::worker_pipeline::3.371*1.79] mapped 7 sequences
# [M::main] Version: 2.14-r886-dirty
# [M::main] CMD: minimap2 -a /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa ./yeastgenome_refinedgraph/contigs/contigs.fasta
# [M::main] Real time: 3.380 sec; CPU: 6.051 sec; Peak RSS: 0.308 GB

# %%
# obtain all contigs to one file
project_name = "yeastcanu"
reference_genome = "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa"


![ -e "$project_name" ] && rm -r "$project_name"
# !mkdir "$project_name"
![ ! -e "$project_name"/mappings ] && mkdir "$project_name"/mappings
![ ! -e "$project_name"/quast_eval ] && mkdir "$project_name"/quast_eval 

# !quast.py -a all -o ./"$project_name"/quast_eval/ -r "$reference_genome" -t 16 "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Yeast/r1.contigs.fasta"

# !minimap2 -a "$reference_genome" "/media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Yeast/r1.contigs.fasta" > ./"$project_name"/mappings/CANU_alignment.sam
# Out:
# /home/anuradhawick/anaconda3/lib/python3.6/site-packages/quast-5.0.2-py3.6.egg/EGG-INFO/scripts/quast.py -a all -o ./yeastcanu/quast_eval/ -r /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa -t 16 /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Yeast/r1.contigs.fasta
#
# Version: 5.0.2
#
# System information:
#   OS: Linux-4.15.0-43-generic-x86_64-with-debian-buster-sid (linux_64)
#   Python version: 3.6.5
#   CPUs number: 8
#
# Started: 2019-01-04 16:44:53
#
# Logging to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/quast.log
#
# CWD: /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations
# Main parameters:
#   MODE: default, threads: 16, minimum contig length: 500, minimum alignment length: 65, \
#   ambiguity: all, threshold for extensive misassembly size: 1000
#
# Reference:
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Sample_Genomes/yeast/YeastGenome.fa ==> YeastGenome
#
# Contigs:
#   Pre-processing...
#   /media/anuradhawick/data/Experiments/Assembly_Graph/Assembly/Canu/Out Yeast/r1.contigs.fasta ==> r1.contigs
#
# 2019-01-04 16:44:54
# Running Basic statistics processor...
#   Reference genome:
#     YeastGenome.fa, length = 12157105, num fragments = 1, GC % = 38.15
#   Contig files:
#     r1.contigs
#   Calculating N50 and L50...
#     r1.contigs, N50 = 8690606, L50 = 1, Total length = 12224431, GC % = 38.16, # N's per 100 kbp =  0.00
#   Drawing Nx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/basic_stats/Nx_plot.pdf
#   Drawing NGx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/basic_stats/NGx_plot.pdf
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/basic_stats/cumulative_plot.pdf
#   Drawing GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/basic_stats/GC_content_plot.pdf
#   Drawing r1.contigs GC content plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/basic_stats/r1.contigs_GC_content_plot.pdf
# Done.
#
# 2019-01-04 16:44:55
# Running Contig analyzer...
#   r1.contigs
#   Logging to files /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/contigs_reports/contigs_report_r1-contigs.stdout and contigs_report_r1-contigs.stderr...
#   Aligning contigs to the reference
#   Analysis is finished.
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/contigs_reports/misassemblies_report.txt, misassemblies_report.tsv, and misassemblies_report.tex
#   Transposed version of total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/contigs_reports/transposed_report_misassemblies.txt, transposed_report_misassemblies.tsv, and transposed_report_misassemblies.tex
#   Creating total report...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/contigs_reports/unaligned_report.txt, unaligned_report.tsv, and unaligned_report.tex
#   Drawing misassemblies by types plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/contigs_reports/misassemblies_plot.pdf
#   Drawing misassemblies FRCurve plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/contigs_reports/misassemblies_frcurve_plot.pdf
# Done.
#
# 2019-01-04 16:45:00
# Running NA-NGA calculation...
#   r1.contigs, Largest alignment = 8683611, NA50 = 8683611, NGA50 = 8683611, LA50 = 1, LGA50 = 1
#   Drawing cumulative plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/aligned_stats/cumulative_plot.pdf
#   Drawing NAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/aligned_stats/NAx_plot.pdf
#   Drawing NGAx plot...
#     saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/aligned_stats/NGAx_plot.pdf
# Done.
#
# 2019-01-04 16:45:01
# Running Genome analyzer...
#   NOTICE: No file with genomic features were provided. Use the --features option if you want to specify it.
#
#   NOTICE: No file with operons were provided. Use the -O option if you want to specify it.
#   r1.contigs
#   Analysis is finished.
#   Skipping drawing Genome fraction, % histogram... (less than 2 columns histogram makes no sense)
# Done.
#
# NOTICE: Genes are not predicted by default. Use --gene-finding or --glimmer option to enable it.
#
# 2019-01-04 16:45:03
# Creating large visual summaries...
# This may take a while: press Ctrl-C to skip this step..
#   1 of 2: Creating Icarus viewers...
#   2 of 2: Creating PDF with all tables and plots...
# Done
#
# 2019-01-04 16:45:04
# RESULTS:
#   Text versions of total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/report.txt, report.tsv, and report.tex
#   Text versions of transposed total report are saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/transposed_report.txt, transposed_report.tsv, and transposed_report.tex
#   HTML version (interactive tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/report.html
#   PDF version (tables and plots) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/report.pdf
#   Icarus (contig browser) is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/icarus.html
#   Log is saved to /media/anuradhawick/data/Experiments/Assembly_Graph/Estimating_actual_contig_locations/yeastcanu/quast_eval/quast.log
#
# Finished: 2019-01-04 16:45:04
# Elapsed time: 0:00:11.178189
# NOTICEs: 3; WARNINGs: 0; non-fatal ERRORs: 0
#
# Thank you for using QUAST!
